# %%
import numpy as np
import control_readconfig as ctrl
# Out:
# Matplotlib is building the font cache; this may take a moment.
# Fontconfig warning: ignoring UTF-8: not a valid region tag
# 2024-09-22 16:50:15.641 system_profiler[12685:2032539] CoreText note: Client requested name ".AlBayanPUA", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# 2024-09-22 16:50:15.641 system_profiler[12685:2032539] CoreText note: Set a breakpoint on CTFontLogSystemFontNameRequest to debug.
# 2024-09-22 16:50:15.649 system_profiler[12685:2032539] CoreText note: Client requested name ".AlBayanPUA-Bold", it will get Times-Roman rather than the intended font. All system UI font access should be through proper APIs such as CTFontCreateUIFontForLanguage() or +[NSFont systemFontOfSize:].
# ...

# %%
#parametros
#test
#nm = [3]
# all
nm = 0

# %%
# MOV 1
#bajo la velocidad
ctrl.send_conf(2,nmod=nm,tipo='vel')
ctrl.send_conf(2,nmod=nm,tipo='acl')
# Out:
# Sending 192.168.0.11[0, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20]
# Sending 192.168.0.12[0, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20]
# Sending 192.168.0.13[0, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20]
# Sending 192.168.0.14[0, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20]
# Sending 192.168.0.15[0, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20]
# Sending 192.168.0.11[0, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20]
# Sending 192.168.0.12[0, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20]
# Sending 192.168.0.13[0, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20]
# Sending 192.168.0.14[0, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20]
# ...

# %%
# Estado actual
conf = np.zeros((5,20))

# %% [markdown]
# # Camara Ciega. Random

# %%
conf = ctrl.load_conf(51)
ctrl.plot_configh(conf,True)
ctrl.send_config(conf,nmod=0,tipo='trg')
# Out:
# Sending 192.168.0.11[0, 62, 235, 243, 163, 127, 24, 208, 64, 139, 251, 56, 239, 254, 172, 228, 203, 63, 117, 128, 91]
# Sending 192.168.0.12[0, 224, 127, 101, 179, 175, 79, 86, 55, 182, 48, 22, 116, 160, 207, 143, 99, 14, 163, 160, 131]
# Sending 192.168.0.13[0, 199, 61, 20, 201, 102, 102, 223, 235, 179, 104, 241, 239, 75, 1, 87, 2, 231, 111, 239, 214]
# Sending 192.168.0.14[0, 221, 10, 140, 193, 115, 190, 111, 64, 178, 165, 220, 217, 98, 66, 139, 240, 111, 193, 180, 86]
# Sending 192.168.0.15[0, 221, 191, 252, 17, 144, 17, 16, 250, 161, 154, 219, 206, 155, 158, 168, 21, 107, 233, 65, 28]

# %% [markdown]
# # Entrada todos hacia el frente
# (derecha de la escena)

# %%
conf = ctrl.load_conf(2)
ctrl.plot_configh(conf,True)
ctrl.send_config(conf,nmod=0,tipo='trg')
# Out:
# Sending 192.168.0.11[0, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214]
# Sending 192.168.0.12[0, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214]
# Sending 192.168.0.13[0, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214]
# Sending 192.168.0.14[0, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214]
# Sending 192.168.0.15[0, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214]

# %% [markdown]
# ## Configuracion oscilante a 45
# **El viento el agua la musica y el polvo**, a 45 hacia un lado y hacia el otro (45 y 135) y luego simetrico

# %%
conf = ctrl.load_conf(4)
ctrl.plot_configh(conf,True)
ctrl.send_config(conf,nmod=0,tipo='trg')
# Out:
# Sending 192.168.0.11[0, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171]
# Sending 192.168.0.12[0, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171]
# Sending 192.168.0.13[0, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171]
# Sending 192.168.0.14[0, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171]
# Sending 192.168.0.15[0, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171]

# %%
conf = ctrl.load_conf(9)
ctrl.plot_configh(conf,True)
ctrl.send_config(conf,nmod=0,tipo='trg')
# Out:
# Sending 192.168.0.11[0, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255]
# Sending 192.168.0.12[0, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255]
# Sending 192.168.0.13[0, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255]
# Sending 192.168.0.14[0, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255]
# Sending 192.168.0.15[0, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255]

# %%
confs = [9,9,2,4,4]; mods = [1,2,3,4,5]
for n,num in enumerate(confs):
    confp = ctrl.load_conf(num)
    conf[mods[n]-1] = np.copy(confp[mods[n]-1])
    ctrl.send_config(confp, [mods[n]], tipo='trg')
ctrl.plot_configh(conf,True)
# Out:
# Sending 192.168.0.11[0, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255]
# Sending 192.168.0.12[0, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255]
# Sending 192.168.0.13[0, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214]
# Sending 192.168.0.14[0, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171]
# Sending 192.168.0.15[0, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171]

# %%
confs = [4,4,9,9]; mods = [1,2,4,5]
for n,num in enumerate(confs):
    confp = ctrl.load_conf(num)
    conf[mods[n]-1] = np.copy(confp[mods[n]-1])
    ctrl.send_config(confp, [mods[n]], tipo='trg')
ctrl.plot_configh(conf,True)
# Out:
# Sending 192.168.0.11[0, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171]
# Sending 192.168.0.12[0, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171]
# Sending 192.168.0.14[0, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255]
# Sending 192.168.0.15[0, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255]

# %% [markdown]
# # MOvimiento Cristales a Posicion 2

# %% [markdown]
# ## Demasiados cadaveres en su bodega
# Agregar movimiento intermedio

# %% [markdown]
# ## Random

# %%
conf = ctrl.load_conf(50)
ctrl.plot_configh(conf,True)
ctrl.send_config(conf,nmod=0,tipo='trg')
# Out:
# Sending 192.168.0.11[0, 203, 246, 228, 202, 77, 207, 125, 248, 237, 243, 108, 13, 243, 49, 233, 35, 242, 133, 70, 74]
# Sending 192.168.0.12[0, 206, 63, 8, 74, 104, 2, 7, 135, 126, 49, 117, 151, 226, 59, 65, 247, 197, 169, 200, 162]
# Sending 192.168.0.13[0, 185, 36, 68, 111, 242, 106, 150, 230, 148, 66, 138, 183, 213, 72, 182, 69, 229, 218, 151, 147]
# Sending 192.168.0.14[0, 128, 172, 72, 105, 61, 104, 148, 198, 205, 216, 203, 181, 230, 3, 150, 200, 198, 230, 207, 125]
# Sending 192.168.0.15[0, 126, 46, 24, 242, 177, 12, 88, 131, 11, 83, 163, 156, 204, 10, 146, 67, 218, 180, 204, 222]

# %% [markdown]
# ## La casa de las munecas ciegas
#
# Alterna Random con pos 0 ??

# %%
confs = [0,0]; mods = [1,2]
for n,num in enumerate(confs):
    confp = ctrl.load_conf(num)
    conf[mods[n]] = np.copy(confp[mods[n]])
    ctrl.send_config(confp, [mods[n]], tipo='trg')
ctrl.plot_configh(conf,True)
# Out:
# Sending 192.168.0.11[0, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Sending 192.168.0.12[0, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128]

# %%
# Agregar mas movimiento

# %%
ctrl.send_conf(1,nmod=nm,tipo='vel')
ctrl.send_conf(1,nmod=nm,tipo='acl')
# Out:
# Sending 192.168.0.11[0, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255]
# Sending 192.168.0.12[0, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255]
# Sending 192.168.0.13[0, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255]
# Sending 192.168.0.14[0, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255]
# Sending 192.168.0.15[0, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255]
# Sending 192.168.0.11[0, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255]
# Sending 192.168.0.12[0, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255]
# ...

# %%
# MOV2
#escalonado

# %%
# MOV 3
# GLISSANDO minuto 16

# %% [markdown]
# # El Laberinto

# %%
# MOV 4 min 17 30
############
# LABERINTO
# para atras todos
conf = ctrl.load_conf(2)
ctrl.plot_configh(conf,True)
ctrl.send_config(conf,nmod=0,tipo='trg')
# Out:
# Sending 192.168.0.11[0, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214]
# Sending 192.168.0.12[0, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214]
# Sending 192.168.0.13[0, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214]
# Sending 192.168.0.14[0, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214]
# Sending 192.168.0.15[0, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214]

# %%
#posicion random de a pasos por columna elegida al azar Piano y Sopranos
ctrl.send_rand_mask(2,5,range(5))
# Out:
# Sending 192.168.0.11[0, 0, 0, 0, 214, 0, 0, 0, 0, 0, 214, 214, 0, 0, 0, 0, 0, 214, 0, 0, 0]
# Sending 192.168.0.12[0, 0, 0, 0, 0, 214, 0, 0, 0, 214, 0, 214, 0, 0, 0, 0, 0, 0, 0, 0, 214]
# Sending 192.168.0.13[0, 214, 0, 0, 0, 0, 0, 0, 0, 0, 214, 0, 0, 214, 0, 0, 0, 0, 214, 0, 0]
# Sending 192.168.0.14[0, 214, 0, 0, 0, 0, 0, 0, 0, 0, 214, 0, 214, 0, 0, 0, 214, 0, 0, 0, 0]
# Sending 192.168.0.15[0, 0, 0, 214, 0, 0, 0, 0, 0, 214, 0, 0, 0, 0, 0, 214, 0, 0, 214, 0, 0]
# Sending 192.168.0.11[0, 0, 214, 0, 0, 0, 0, 0, 0, 214, 0, 0, 0, 0, 0, 214, 0, 0, 214, 0, 0]
# Sending 192.168.0.12[0, 0, 0, 214, 0, 0, 0, 0, 214, 0, 0, 0, 0, 214, 0, 0, 0, 0, 0, 214, 0]
# Sending 192.168.0.13[0, 0, 0, 0, 0, 214, 0, 214, 0, 0, 0, 0, 0, 0, 0, 214, 214, 0, 0, 0, 0]
# Sending 192.168.0.14[0, 0, 0, 214, 0, 0, 0, 0, 0, 214, 0, 214, 0, 0, 0, 0, 0, 0, 0, 0, 214]
# Sending 192.168.0.15[0, 0, 214, 0, 0, 0, 0, 0, 0, 0, 214, 214, 0, 0, 0, 0, 0, 214, 0, 0, 0]
# ...

# %% [markdown]
# ## Piano y Stacatto

# %%
#mueve de a 1 columna por fila al azar
ctrl.send_rand_mask(0,5,nmask = range(5))
#ctrl.send_rand_mask(1,0,nmod=nm,nmask = [0], tipo='rgb')
# Out:
# Sending 192.168.0.11[0, 0, 0, 128, 0, 0, 128, 0, 0, 0, 0, 0, 128, 0, 0, 0, 128, 0, 0, 0, 0]
# Sending 192.168.0.12[0, 0, 0, 0, 128, 0, 0, 0, 0, 0, 128, 0, 0, 0, 0, 128, 0, 0, 0, 128, 0]
# Sending 192.168.0.13[0, 0, 0, 0, 0, 128, 128, 0, 0, 0, 0, 0, 128, 0, 0, 0, 0, 128, 0, 0, 0]
# Sending 192.168.0.14[0, 0, 0, 0, 0, 128, 0, 128, 0, 0, 0, 0, 0, 0, 0, 128, 0, 0, 0, 128, 0]
# Sending 192.168.0.15[0, 0, 0, 0, 128, 0, 0, 0, 128, 0, 0, 128, 0, 0, 0, 0, 0, 0, 0, 0, 128]
# Sending 192.168.0.11[0, 0, 128, 0, 0, 0, 0, 128, 0, 0, 0, 0, 0, 0, 0, 128, 0, 0, 0, 128, 0]
# Sending 192.168.0.12[0, 0, 128, 0, 0, 0, 128, 0, 0, 0, 0, 0, 0, 0, 128, 0, 0, 128, 0, 0, 0]
# Sending 192.168.0.13[0, 128, 0, 0, 0, 0, 0, 0, 0, 128, 0, 0, 0, 0, 0, 128, 0, 0, 128, 0, 0]
# Sending 192.168.0.14[0, 0, 128, 0, 0, 0, 0, 0, 0, 128, 0, 0, 128, 0, 0, 0, 0, 0, 128, 0, 0]
# Sending 192.168.0.15[0, 0, 128, 0, 0, 0, 128, 0, 0, 0, 0, 0, 0, 128, 0, 0, 128, 0, 0, 0, 0]
# ...

# %%
# Rueda que rueda la rueda de la fortun min 18 30

# %% [markdown]
# ## El señor de los espejos

# %%
# Entrada Random
conf = ctrl.load_conf(50)
ctrl.plot_configh(conf,True)
ctrl.send_config(conf,nmod=0,tipo='trg')
# Out:
# Sending 192.168.0.11[0, 203, 246, 228, 202, 77, 207, 125, 248, 237, 243, 108, 13, 243, 49, 233, 35, 242, 133, 70, 74]
# Sending 192.168.0.12[0, 206, 63, 8, 74, 104, 2, 7, 135, 126, 49, 117, 151, 226, 59, 65, 247, 197, 169, 200, 162]
# Sending 192.168.0.13[0, 185, 36, 68, 111, 242, 106, 150, 230, 148, 66, 138, 183, 213, 72, 182, 69, 229, 218, 151, 147]
# Sending 192.168.0.14[0, 128, 172, 72, 105, 61, 104, 148, 198, 205, 216, 203, 181, 230, 3, 150, 200, 198, 230, 207, 125]
# Sending 192.168.0.15[0, 126, 46, 24, 242, 177, 12, 88, 131, 11, 83, 163, 156, 204, 10, 146, 67, 218, 180, 204, 222]

# %%
# Orden Controlo las cabezas
confs = [0,0]; mods = [1,2]
for n,num in enumerate(confs):
    confp = ctrl.load_conf(num)
    conf[mods[n]] = np.copy(confp[mods[n]])
    ctrl.send_config(confp, [mods[n]], tipo='trg')
ctrl.plot_configh(conf,True)
# Out:
# Sending 192.168.0.11[0, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Sending 192.168.0.12[0, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128]

# %%
# Orden Controlo el Tiempo el Tiempo (>?)
confs = [1,1,0,2,2]; mods = [1,2,3,4,5]
for n,num in enumerate(confs):
    confp = ctrl.load_conf(num)
    conf[mods[n]-1] = np.copy(confp[mods[n]-1])
    ctrl.send_config(confp, [mods[n]], tipo='trg')
ctrl.plot_configh(conf,True)
# Out:
# Sending 192.168.0.11[0, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42]
# Sending 192.168.0.12[0, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42]
# Sending 192.168.0.13[0, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Sending 192.168.0.14[0, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214]
# Sending 192.168.0.15[0, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214]

# %% [markdown]
# # Duo de Saxos

# %%
# MOV 5
#######
# DUO DE SAXOS
confs = [5,6]; mods = [1,4]
for n,num in enumerate(confs):
    confp = ctrl.load_conf(num)
    conf[mods[n]-1] = np.copy(confp[mods[n]-1])
    ctrl.send_config(confp, [mods[n]], tipo='trg')
ctrl.plot_configh(conf,True)
# Out:
# Sending 192.168.0.11[0, 214, 214, 214, 214, 214, 42, 42, 42, 42, 42, 214, 214, 214, 214, 214, 42, 42, 42, 42, 42]
# Sending 192.168.0.14[0, 42, 42, 42, 42, 42, 214, 214, 214, 214, 214, 42, 42, 42, 42, 42, 214, 214, 214, 214, 214]

# %%
confs = [6,5]; mods = [1,4]
for n,num in enumerate(confs):
    confp = ctrl.load_conf(num)
    conf[mods[n]-1] = np.copy(confp[mods[n]-1])
    ctrl.send_config(confp, [mods[n]], tipo='trg')
ctrl.plot_configh(conf,True)
# Out:
# Sending 192.168.0.11[0, 42, 42, 42, 42, 42, 214, 214, 214, 214, 214, 42, 42, 42, 42, 42, 214, 214, 214, 214, 214]
# Sending 192.168.0.14[0, 214, 214, 214, 214, 214, 42, 42, 42, 42, 42, 214, 214, 214, 214, 214, 42, 42, 42, 42, 42]

# %%
confs = [8,7]; mods = [1,4]
for n,num in enumerate(confs):
    confp = ctrl.load_conf(num)
    conf[mods[n]-1] = np.copy(confp[mods[n]-1])
    ctrl.send_config(confp, [mods[n]], tipo='trg')
ctrl.plot_configh(conf,True)
# Out:
# Sending 192.168.0.11[0, 214, 42, 214, 42, 214, 214, 42, 214, 42, 214, 214, 42, 214, 42, 214, 214, 42, 214, 42, 214]
# Sending 192.168.0.14[0, 42, 214, 42, 214, 42, 42, 214, 42, 214, 42, 42, 214, 42, 214, 42, 42, 214, 42, 214, 42]

# %%
confs = [7,8,7,8,7]; mods = [0,1,2,3,4]
for n,num in enumerate(confs):
    confp = ctrl.load_conf(num)
    conf[mods[n]-1] = np.copy(confp[mods[n]-1])
    ctrl.send_config(confp, [mods[n]], tipo='trg')
ctrl.plot_configh(conf,True)
# Out:
# Sending 192.168.0.15[0, 42, 214, 42, 214, 42, 42, 214, 42, 214, 42, 42, 214, 42, 214, 42, 42, 214, 42, 214, 42]
# Sending 192.168.0.11[0, 214, 42, 214, 42, 214, 214, 42, 214, 42, 214, 214, 42, 214, 42, 214, 214, 42, 214, 42, 214]
# Sending 192.168.0.12[0, 42, 214, 42, 214, 42, 42, 214, 42, 214, 42, 42, 214, 42, 214, 42, 42, 214, 42, 214, 42]
# Sending 192.168.0.13[0, 214, 42, 214, 42, 214, 214, 42, 214, 42, 214, 214, 42, 214, 42, 214, 214, 42, 214, 42, 214]
# Sending 192.168.0.14[0, 42, 214, 42, 214, 42, 42, 214, 42, 214, 42, 42, 214, 42, 214, 42, 42, 214, 42, 214, 42]

# %%
conf = ctrl.load_conf(2)
ctrl.plot_configh(conf,True)
ctrl.send_config(conf,nmod=0,tipo='trg')
# Out:
# Sending 192.168.0.11[0, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214]
# Sending 192.168.0.12[0, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214]
# Sending 192.168.0.13[0, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214]
# Sending 192.168.0.14[0, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214]
# Sending 192.168.0.15[0, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214]

# %%
confs = [7,8,7,8,7]; mods = [0,1,2,3,4]
for n,num in enumerate(confs):
    confp = ctrl.load_conf(num)
    conf[mods[n]-1] = np.copy(confp[mods[n]-1])
    ctrl.send_config(confp, [mods[n]], tipo='trg')
ctrl.plot_configh(conf,True)
# Out:
# Sending 192.168.0.15[0, 42, 214, 42, 214, 42, 42, 214, 42, 214, 42, 42, 214, 42, 214, 42, 42, 214, 42, 214, 42]
# Sending 192.168.0.11[0, 214, 42, 214, 42, 214, 214, 42, 214, 42, 214, 214, 42, 214, 42, 214, 214, 42, 214, 42, 214]
# Sending 192.168.0.12[0, 42, 214, 42, 214, 42, 42, 214, 42, 214, 42, 42, 214, 42, 214, 42, 42, 214, 42, 214, 42]
# Sending 192.168.0.13[0, 214, 42, 214, 42, 214, 214, 42, 214, 42, 214, 214, 42, 214, 42, 214, 214, 42, 214, 42, 214]
# Sending 192.168.0.14[0, 42, 214, 42, 214, 42, 42, 214, 42, 214, 42, 42, 214, 42, 214, 42, 42, 214, 42, 214, 42]

# %%
ctrl.print_configh_seq(12,2,True)

# %%
ctrl.print_configh_seq(13,2)

# %%
#atencion porque queda en loop
ctrl.send_conf_delay(12,[2,2],nmod=nm,loop=1)
# Out:
# Sending 192.168.0.11[0, 0, 0, 171, 0, 0, 0, 0, 171, 0, 0, 0, 0, 171, 0, 0, 0, 0, 171, 0, 0]
# Sending 192.168.0.12[0, 0, 0, 171, 0, 0, 0, 0, 171, 0, 0, 0, 0, 171, 0, 0, 0, 0, 171, 0, 0]
# Sending 192.168.0.13[0, 0, 0, 171, 0, 0, 0, 0, 171, 0, 0, 0, 0, 171, 0, 0, 0, 0, 171, 0, 0]
# Sending 192.168.0.14[0, 0, 0, 171, 0, 0, 0, 0, 171, 0, 0, 0, 0, 171, 0, 0, 0, 0, 171, 0, 0]
# Sending 192.168.0.15[0, 0, 0, 171, 0, 0, 0, 0, 171, 0, 0, 0, 0, 171, 0, 0, 0, 0, 171, 0, 0]
# Sending 192.168.0.11[0, 0, 0, 255, 0, 0, 0, 0, 255, 0, 0, 0, 0, 255, 0, 0, 0, 0, 255, 0, 0]
# Sending 192.168.0.12[0, 0, 0, 255, 0, 0, 0, 0, 255, 0, 0, 0, 0, 255, 0, 0, 0, 0, 255, 0, 0]
# Sending 192.168.0.13[0, 0, 0, 255, 0, 0, 0, 0, 255, 0, 0, 0, 0, 255, 0, 0, 0, 0, 255, 0, 0]
# Sending 192.168.0.14[0, 0, 0, 255, 0, 0, 0, 0, 255, 0, 0, 0, 0, 255, 0, 0, 0, 0, 255, 0, 0]
# Sending 192.168.0.15[0, 0, 0, 255, 0, 0, 0, 0, 255, 0, 0, 0, 0, 255, 0, 0, 0, 0, 255, 0, 0]
# ...

# %%
ctrl.send_conf_delay(13,[8,8],loop=1)
# Out:
# Sending 192.168.0.11[0, 0, 171, 171, 171, 0, 0, 171, 171, 171, 0, 0, 171, 171, 171, 0, 0, 171, 171, 171, 0]
# Sending 192.168.0.12[0, 0, 171, 171, 171, 0, 0, 171, 171, 171, 0, 0, 171, 171, 171, 0, 0, 171, 171, 171, 0]
# Sending 192.168.0.13[0, 0, 171, 171, 171, 0, 0, 171, 171, 171, 0, 0, 171, 171, 171, 0, 0, 171, 171, 171, 0]
# Sending 192.168.0.14[0, 0, 171, 171, 171, 0, 0, 171, 171, 171, 0, 0, 171, 171, 171, 0, 0, 171, 171, 171, 0]
# Sending 192.168.0.15[0, 0, 171, 171, 171, 0, 0, 171, 171, 171, 0, 0, 171, 171, 171, 0, 0, 171, 171, 171, 0]
# Sending 192.168.0.11[0, 0, 255, 255, 255, 0, 0, 255, 255, 255, 0, 0, 255, 255, 255, 0, 0, 255, 255, 255, 0]
# Sending 192.168.0.12[0, 0, 255, 255, 255, 0, 0, 255, 255, 255, 0, 0, 255, 255, 255, 0, 0, 255, 255, 255, 0]
# Sending 192.168.0.13[0, 0, 255, 255, 255, 0, 0, 255, 255, 255, 0, 0, 255, 255, 255, 0, 0, 255, 255, 255, 0]
# Sending 192.168.0.14[0, 0, 255, 255, 255, 0, 0, 255, 255, 255, 0, 0, 255, 255, 255, 0, 0, 255, 255, 255, 0]
# ...

# %%
ctrl.send_conf_delay(14,[8,8],nmod=nm,loop=1)
# Out:
# Sending 192.168.0.11[0, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171]
# Sending 192.168.0.12[0, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171]
# Sending 192.168.0.13[0, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171]
# Sending 192.168.0.14[0, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171]
# Sending 192.168.0.15[0, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171, 171]
# Sending 192.168.0.11[0, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255]
# Sending 192.168.0.12[0, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255]
# ...

# %%
ctrl.send_conf_delay(13,[8,8],nmod=nm)
# Out:
# Sending 192.168.0.14[0, 0, 171, 171, 171, 0, 0, 171, 171, 171, 0, 0, 171, 171, 171, 0, 0, 171, 171, 171, 0]
# Sending 192.168.0.14[0, 0, 255, 255, 255, 0, 0, 255, 255, 255, 0, 0, 255, 255, 255, 0, 0, 255, 255, 255, 0]

# %%
ctrl.send_conf(0)
# Out:
# Sending 192.168.0.11[0, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Sending 192.168.0.12[0, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Sending 192.168.0.13[0, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Sending 192.168.0.14[0, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Sending 192.168.0.15[0, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128]

# %%
# MOV 7
####
#CASA POLITICA
# Se apagan todos. Movimientos simetricos de los modulos 3 y 4 a 45
ctrl.send_conf_list([1,2,0,2,1],[0,1,4,2,3])
# Out:
# Sending 192.168.0.11[0, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42]
# Sending 192.168.0.12[0, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214]
# Sending 192.168.0.15[0, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Sending 192.168.0.13[0, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214]
# Sending 192.168.0.14[0, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42]
