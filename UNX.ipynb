# %%
import numpy as np
import control_readconfig as ctrl

# %%
# Inicio
ctrl.send_conf(1,nmod=[2],tipo='pos')
ctrl.send_conf(1,nmod=0,tipo='rgb')
# Out:
# Sending 192.168.0.13[0, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42]
# Sending 192.168.0.11[0, 255, 0, 0, 10, 255, 0, 0, 10, 255, 0, 0, 10, 255, 0, 0, 10, 255, 0, 0, 10, 255, 0, 0, 10, 255, 0, 0, 10, 255, 0, 0, 10, 255, 0, 0, 10, 255, 0, 0, 10, 255, 0, 0, 10, 255, 0, 0, 10, 255, 0, 0, 10, 255, 0, 0, 10, 255, 0, 0, 10, 255, 0, 0, 10, 255, 0, 0, 10, 255, 0, 0, 10, 255, 0, 0, 10, 255, 0, 0, 10]
# Sending 192.168.0.12[0, 255, 0, 0, 10, 255, 0, 0, 10, 255, 0, 0, 10, 255, 0, 0, 10, 255, 0, 0, 10, 255, 0, 0, 10, 255, 0, 0, 10, 255, 0, 0, 10, 255, 0, 0, 10, 255, 0, 0, 10, 255, 0, 0, 10, 255, 0, 0, 10, 255, 0, 0, 10, 255, 0, 0, 10, 255, 0, 0, 10, 255, 0, 0, 10, 255, 0, 0, 10, 255, 0, 0, 10, 255, 0, 0, 10, 255, 0, 0, 10]
# ...

# %%
# Parte 1
ctrl.send_conf(0,nmod=[2])
# Out:
# Sending 192.168.0.13[0, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128]

# %%
ctrl.send_conf_list([1,2],[0,3])
# Out:
# Sending 192.168.0.11[0, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42]
# Sending 192.168.0.14[0, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214, 214]

# %%
ctrl.send_conf_list([0,1],[0,1])
# Out:
# Sending 192.168.0.11[0, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Sending 192.168.0.12[0, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42, 42]

# %%
ctrl.send_rand_mask(1,delay=5,nmask=range(5))
# Out:
# Sending 192.168.0.11[0, 0, 0, 0, 42, 0, 0, 42, 0, 0, 0, 0, 0, 0, 0, 42, 0, 0, 0, 42, 0]
# Sending 192.168.0.12[0, 0, 0, 0, 0, 42, 42, 0, 0, 0, 0, 42, 0, 0, 0, 0, 0, 0, 42, 0, 0]
# Sending 192.168.0.13[0, 42, 0, 0, 0, 0, 0, 0, 0, 0, 42, 0, 0, 42, 0, 0, 0, 0, 42, 0, 0]
# Sending 192.168.0.14[0, 0, 0, 42, 0, 0, 0, 42, 0, 0, 0, 0, 0, 0, 0, 42, 0, 0, 0, 0, 42]
# Sending 192.168.0.15[0, 0, 0, 0, 0, 42, 0, 0, 0, 42, 0, 0, 42, 0, 0, 0, 0, 0, 42, 0, 0]
# Sending 192.168.0.11[0, 0, 0, 0, 0, 42, 0, 0, 0, 0, 42, 0, 0, 0, 42, 0, 0, 42, 0, 0, 0]
# Sending 192.168.0.12[0, 0, 42, 0, 0, 0, 0, 0, 0, 42, 0, 0, 0, 0, 0, 42, 0, 0, 0, 0, 42]
# Sending 192.168.0.13[0, 0, 42, 0, 0, 0, 0, 0, 0, 42, 0, 0, 42, 0, 0, 0, 0, 0, 0, 42, 0]
# Sending 192.168.0.14[0, 42, 0, 0, 0, 0, 0, 0, 0, 0, 42, 0, 0, 0, 42, 0, 0, 0, 0, 42, 0]
# Sending 192.168.0.15[0, 0, 0, 42, 0, 0, 0, 42, 0, 0, 0, 42, 0, 0, 0, 0, 0, 0, 0, 0, 42]
# Sending 192.168.0.11[0, 0, 42, 0, 0, 0, 42, 0, 0, 0, 0, 0, 0, 42, 0, 0, 42, 0, 0, 0, 0]
# ...
